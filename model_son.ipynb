# %%
import json

with open("data/merged.json", "r", encoding="utf-8") as f:
    data = json.load(f)

# %%
TRAIN_DATA = []

for item in data:
    text = item["text"]
    entities = []

    for ent in item["entities"]:
        start = ent["start_offset"]
        end = ent["end_offset"]
        label = ent["label"]
        entities.append((start, end, label))

    TRAIN_DATA.append((text, {"entities": entities}))

# %%
import spacy
from spacy.training import Example
import re

def preprocess_text(text):
    text = text.lower()
    text = re.sub(r'\s+', ' ', text).strip()
    return text

def adjust_entity_offsets(text, original_text, entities):
    adjusted_entities = []
    original_words = original_text.split()
    processed_words = text.split()

    offset_map = {}
    original_idx = 0
    for word in processed_words:
        while original_idx < len(original_words) and original_words[original_idx].lower() != word:
            original_idx += 1
        if original_idx < len(original_words):
            offset_map[original_idx] = len(' '.join(processed_words[:processed_words.index(word)]))
            original_idx += 1

    for start, end, label in entities:
        new_start = offset_map.get(start)
        new_end = offset_map.get(end-1) + len(original_words[end-1]) if end-1 in offset_map else end
        if new_start is not None and new_end is not None:
            adjusted_entities.append((new_start, new_end, label))

    return adjusted_entities

def preprocess_data(data):
    preprocessed_data = []
    for text, annotations in data:
        preprocessed_text = preprocess_text(text)
        adjusted_entities = adjust_entity_offsets(preprocessed_text, text, annotations.get("entities"))
        filtered_entities = filter_overlapping_entities(adjusted_entities)
        preprocessed_data.append((preprocessed_text, {"entities": filtered_entities}))
    return preprocessed_data

def filter_overlapping_entities(entities):
    entities = sorted(entities, key=lambda x: x[0]) 
    filtered_entities = []
    last_end = -1

    for start, end, label in entities:
        if start >= last_end:
            filtered_entities.append((start, end, label))
            last_end = end

    return filtered_entities

TRAIN_DATA = preprocess_data(TRAIN_DATA)
nlp = spacy.blank("tr")
ner = nlp.add_pipe("ner")


for _, annotations in TRAIN_DATA:
    for ent in annotations.get("entities"):
        ner.add_label(ent[2])

optimizer = nlp.begin_training()

for i in range(10):
    losses = {}
    for text, annotations in TRAIN_DATA:
        example = Example.from_dict(nlp.make_doc(text), annotations)
        nlp.update([example], losses=losses, drop=0.5, sgd=optimizer)
    print(losses)
# Out:
# c:\Users\LOKMAN\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "turkcell akıllı cihaz olumlu yönleri: turkcell t60..." with entities "[(0, 63, 'Turkcell')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\LOKMAN\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "turkcell akıllı cihaz olumlu yönleri: telefon iyi ..." with entities "[(0, 60, 'Turkcell')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\LOKMAN\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "turkcell akıllı cihaz olumsuz yönleri: sadece inte..." with entities "[(0, 71, 'Turkcell')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\LOKMAN\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "turkcell akıllı cihaz olumlu yönleri: turkcell art..." with entities "[(0, 67, 'Turkcell')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\LOKMAN\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "turkcell akıllı cihaz olumlu yönleri: yiğenime kar..." with entities "[(0, 67, 'Turkcell')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\LOKMAN\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "turkcell akıllı cihaz olumsuz yönleri: şirket tele..." with entities "[(0, 59, 'Turkcell')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\LOKMAN\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "turkcell akıllı cihaz hızlı teslimat geldi.+" with entities "[(0, 9, 'Turkcell')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\LOKMAN\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "turkcell akıllı cihaz turkcell'in kendi sitesinden..." with entities "[(0, 65, 'Turkcell')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\LOKMAN\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "turkcell akıllı cihaz hızlı bir şekilde elimize ul..." with entities "[(0, 68, 'Turkcell')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\LOKMAN\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "turkcell akıllı cihaz ürün fiyat yönünden çok uygu..." with entities "[(0, 55, 'Turkcell')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\LOKMAN\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "turkcell akıllı cihaz hiç açılmamış orjinal ürün 👍..." with entities "[(0, 9, 'Turkcell')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\LOKMAN\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "turkcell akıllı cihaz çok güzel paketlenmiş.ürün f..." with entities "[(0, 65, 'Turkcell')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\LOKMAN\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "turkcell akıllı cihaz telefonu 1-1,5 yıldan beri b..." with entities "[(0, 29, 'Turkcell')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\LOKMAN\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "turkcell akıllı cihaz normal düzgün çalışıyor+" with entities "[(0, 9, 'Turkcell')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\LOKMAN\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "turkcell akıllı cihaz yeğenime iş yeri almış.. çok..." with entities "[(0, 53, 'Turkcell')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\LOKMAN\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "turkcell akıllı cihaz bu fiyata alınabilecek en iy..." with entities "[(0, 59, 'Turkcell')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\LOKMAN\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "turkcell akıllı cihaz dokunmatiğine sert basmak ge..." with entities "[(0, 68, 'Turkcell')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\LOKMAN\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "turkcell akıllı cihaz fiyatina göre en iyi telefon..." with entities "[(0, 58, 'Turkcell')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\LOKMAN\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "turkcell akıllı cihaz fiyatına göre çok iyi telefo..." with entities "[(0, 57, 'Turkcell')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\LOKMAN\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "turkcell akıllı cihaz fiyatı biraz daha düşük olab..." with entities "[(0, 56, 'Turkcell')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\LOKMAN\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "turkcell akıllı cihaz 6 aydır kullanıyorum .donma ..." with entities "[(0, 57, 'Turkcell')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\LOKMAN\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "turkcell akıllı cihaz yaklaşık 4-5 aydır kullanıyo..." with entities "[(0, 58, 'Turkcell')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\LOKMAN\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "turkcell akıllı cihaz daha önce t50'yi kullanmış b..." with entities "[(0, 59, 'Turkcell')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\LOKMAN\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "turkcell akıllı cihaz fiyatına göre oldukça güzel ..." with entities "[(0, 61, 'Turkcell')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\LOKMAN\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "turkcell akıllı cihaz fiyatını az bıçuk kurtarıyor..." with entities "[(0, 54, 'Turkcell')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\LOKMAN\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "turkcell akıllı cihaz sağlam ve güzel bi̇r ürün am..." with entities "[(0, 50, 'Turkcell')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\LOKMAN\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "turkcell akıllı cihaz bu fiyata mantıklı, ben menu..." with entities "[(0, 9, 'Turkcell')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\LOKMAN\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "turkcell akıllı cihaz i̇le için şirket almış kulla..." with entities "[(0, 56, 'Turkcell')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\LOKMAN\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "turkcell akıllı cihaz beğendik.telefon gayet başar..." with entities "[(0, 69, 'Turkcell')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\LOKMAN\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "turkcell akıllı cihaz 1haftadır kullanıyorum . şar..." with entities "[(0, 64, 'Turkcell')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\LOKMAN\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "turkcell akıllı cihaz merhaba, ben turkcell t70 te..." with entities "[(0, 61, 'Turkcell')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\LOKMAN\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "turkcell akıllı cihaz kötü yorumlara aldırmayın te..." with entities "[(0, 75, 'Turkcell')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\LOKMAN\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "turkcell akıllı cihaz güzel begendim+" with entities "[(0, 9, 'Turkcell')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\LOKMAN\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "turkcell akıllı cihaz t70 telefonda gelen mesajlar..." with entities "[(0, 59, 'Turkcell')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\LOKMAN\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "turkcell akıllı cihaz t70 telefonum hedi̇ye geldi̇..." with entities "[(0, 56, 'Turkcell')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\LOKMAN\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "turkcell akıllı cihaz sayın turkcell ,ben bir turk..." with entities "[(0, 63, 'Turkcell')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\LOKMAN\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "turkcell akıllı cihaz iye benziyo+" with entities "[(0, 9, 'Turkcell')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\LOKMAN\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "turkcell akıllı cihaz herkesin almasını tavsiye ed..." with entities "[(0, 74, 'Turkcell')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\LOKMAN\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "turkcell akıllı cihaz snapdragon 2xx kullanıyor iş..." with entities "[(0, 14, 'Turkcell')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\LOKMAN\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "turkcell akıllı cihaz ilk başta iyi idi. 2nci haft..." with entities "[(0, 44, 'Turkcell')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\LOKMAN\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "turkcell akıllı cihaz bu fi̇yata bu telefon güzel ..." with entities "[(0, 56, 'Turkcell')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\LOKMAN\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "turkcell akıllı cihaz kutudan kulaklık çıkmadı, tu..." with entities "[(0, 63, 'Turkcell')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\LOKMAN\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "turkcell akıllı cihaz harika bi telefon. babam kar..." with entities "[(0, 51, 'Turkcell')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\LOKMAN\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "turkcell akıllı cihaz fiyatı bu dandik telefona gö..." with entities "[(0, 58, 'Turkcell')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\LOKMAN\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "turkcell akıllı cihaz turkcell t seri̇si̇ macerama..." with entities "[(0, 57, 'Turkcell')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\LOKMAN\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "turkcell akıllı cihaz i̇nterneti çok hızlı ama kam..." with entities "[(0, 56, 'Turkcell')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\LOKMAN\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "turkcell akıllı cihaz i̇şlemcisi çok daha iyi olab..." with entities "[(0, 9, 'Turkcell')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\LOKMAN\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "turkcell akıllı cihaz t50 - t60 kullanıcısıyım şim..." with entities "[(0, 57, 'Turkcell')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\LOKMAN\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "turkcell akıllı cihaz 7 8aydır kullanıyorum. i̇nte..." with entities "[(0, 73, 'Turkcell')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\LOKMAN\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "turkcell akıllı cihaz arkadaşımında bahsetiği üzer..." with entities "[(0, 81, 'Turkcell')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\LOKMAN\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "turkcell akıllı cihaz turkcell yaparsa böyle yapar..." with entities "[(0, 64, 'Turkcell')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\LOKMAN\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "turkcell akıllı cihaz turkcell t50 kullanıcısı ola..." with entities "[(0, 68, 'Turkcell')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\LOKMAN\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "turkcell akıllı cihaz pi̇l; 2800-2900 mah omasını ..." with entities "[(0, 60, 'Turkcell')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\LOKMAN\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "turkcell akıllı cihaz radyosu olsa, pil ömrü uzatı..." with entities "[(0, 56, 'Turkcell')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\LOKMAN\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "turkcell akıllı cihaz turkcell daha i̇yi̇si̇ni̇ ya..." with entities "[(0, 62, 'Turkcell')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\LOKMAN\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "turkcell akıllı cihaz hadii hayırlısı+" with entities "[(0, 9, 'Turkcell')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\LOKMAN\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "turkcell akıllı cihaz iyi..................+" with entities "[(0, 9, 'Turkcell')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\LOKMAN\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "turkcell akıllı cihaz ürün fiyatına göre çok iyi. ..." with entities "[(0, 62, 'Turkcell')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\LOKMAN\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "turkcell akıllı cihaz evet çok beğendim....+" with entities "[(0, 9, 'Turkcell')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\LOKMAN\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "turkcell akıllı cihaz bildiğim telefon hızlı gönde..." with entities "[(0, 70, 'Turkcell')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\LOKMAN\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "turkcell akıllı cihaz resimlerde göründüğü gibi sa..." with entities "[(0, 63, 'Turkcell')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\LOKMAN\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "turkcell akıllı cihaz turkcell t70 16gb siyah+" with entities "[(0, 9, 'Turkcell')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\LOKMAN\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "turkcell akıllı cihaz çalışmıyan ürün satıyolar+" with entities "[(0, 9, 'Turkcell')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\LOKMAN\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "turkcell akıllı cihaz güzel bı ürün. işimizi halle..." with entities "[(0, 9, 'Turkcell')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\LOKMAN\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "turkcell akıllı cihaz 2 urun aldim biri çalışmıyor..." with entities "[(0, 61, 'Turkcell')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\LOKMAN\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "turkcell akıllı cihaz yanlış marka ürün+" with entities "[(0, 9, 'Turkcell')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\LOKMAN\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "turkcell akıllı cihaz harika ürün güvenilir mağaza..." with entities "[(0, 9, 'Turkcell')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\LOKMAN\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "turkcell akıllı cihaz güzel ürün+" with entities "[(0, 9, 'Turkcell')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\LOKMAN\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "turkcell akıllı cihaz ürün resimde gösterildiği gi..." with entities "[(0, 67, 'Turkcell')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\LOKMAN\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "turkcell akıllı cihaz urun cok eski model.gunumuz ..." with entities "[(0, 81, 'Turkcell')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\LOKMAN\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "turkcell akıllı cihaz modem vodafone da çalışıyor...." with entities "[(0, 66, 'Turkcell'), (192, 37, 'vodafone')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\LOKMAN\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "turkcell akıllı cihaz bilgisayara takar takmaz hem..." with entities "[(0, 64, 'Turkcell')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\LOKMAN\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "turkcell akıllı cihaz hızı çok iyi.zamanida korgoy..." with entities "[(0, 66, 'Turkcell')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\LOKMAN\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "turkcell akıllı cihaz ürününüzü maalesef beğenmedi..." with entities "[(0, 73, 'Turkcell')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\LOKMAN\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "turkcell akıllı cihaz ürün tabi ki güzel, orjinal...." with entities "[(0, 55, 'Turkcell')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\LOKMAN\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "turkcell akıllı cihaz seyehatleri̇ni̇z esnainda ya..." with entities "[(0, 75, 'Turkcell')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\LOKMAN\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "turkcell akıllı cihaz kaliteli hizmet, çok iyi tek..." with entities "[(0, 60, 'Turkcell')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\LOKMAN\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "turkcell akıllı cihaz ürün çok iyi. memnunum. anca..." with entities "[(0, 59, 'Turkcell')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\LOKMAN\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "turkcell akıllı cihaz kesinlikle tavsiye etmiyorum..." with entities "[(0, 90, 'Turkcell')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\LOKMAN\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "turkcell akıllı cihaz berbat bir ürün. annemleri k..." with entities "[(0, 67, 'Turkcell')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\LOKMAN\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "turkcell akıllı cihaz şarj aletinin kablosu yok+" with entities "[(0, 9, 'Turkcell')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\LOKMAN\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "turkcell akıllı cihaz fi̇yatina göre güzel ürün. s..." with entities "[(0, 57, 'Turkcell')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\LOKMAN\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "turkcell akıllı cihaz olumlu yönleri: bu fiyata ga..." with entities "[(0, 61, 'Turkcell')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\LOKMAN\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "turkcell akıllı cihaz olumlu yönleri: harika bir k..." with entities "[(0, 60, 'Turkcell')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\LOKMAN\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "turkcell akıllı cihaz çok kalitesiz, zayıf bir cih..." with entities "[(0, 9, 'Turkcell')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\LOKMAN\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "turkcell akıllı cihaz tablet değil çay tepsisi+" with entities "[(0, 9, 'Turkcell')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\LOKMAN\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "turkcell akıllı cihaz çok memnunuz teşekkür ederim..." with entities "[(0, 9, 'Turkcell')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\LOKMAN\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "turkcell akıllı cihaz cocuklar için alınabilecek g..." with entities "[(0, 64, 'Turkcell')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\LOKMAN\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "turkcell akıllı cihaz çok fazla donuyor.+" with entities "[(0, 9, 'Turkcell')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\LOKMAN\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "turkcell akıllı cihaz urun guzel+" with entities "[(0, 9, 'Turkcell')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\LOKMAN\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "turkcell akıllı cihaz asla tavsiye etmiyorum. biz ..." with entities "[(0, 55, 'Turkcell')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\LOKMAN\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "turkcell akıllı cihaz sürekli donuyor+" with entities "[(0, 9, 'Turkcell')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\LOKMAN\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "turkcell akıllı cihaz olumlu yönleri: güzel tavsiy..." with entities "[(0, 9, 'Turkcell')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\LOKMAN\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "turkcell akıllı cihaz ürün aldım. bozuk çıktı. iad..." with entities "[(0, 61, 'Turkcell')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\LOKMAN\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "turkcell akıllı cihaz çok begendik+" with entities "[(0, 9, 'Turkcell')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\LOKMAN\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "turkcell akıllı cihaz ürün paketlenmesi güzeldi , ..." with entities "[(0, 60, 'Turkcell')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\LOKMAN\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "turkcell akıllı cihaz güzel tablet+" with entities "[(0, 9, 'Turkcell')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\LOKMAN\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "turkcell akıllı cihaz fiyata göre normal.+" with entities "[(0, 9, 'Turkcell')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\LOKMAN\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "turkcell akıllı cihaz çok teşekkür ederim+" with entities "[(0, 9, 'Turkcell')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\LOKMAN\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "turkcell akıllı cihaz sakın bulaşmayın 1,5 ayda ek..." with entities "[(0, 61, 'Turkcell')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\LOKMAN\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "turkcell akıllı cihaz tesekküre kemküm...+" with entities "[(0, 9, 'Turkcell')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\LOKMAN\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "turkcell akıllı cihaz kaliteli ve güzel bir ürün+" with entities "[(0, 9, 'Turkcell')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\LOKMAN\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "turkcell akıllı cihaz olumlu yönleri: turkcell ger..." with entities "[(0, 64, 'Turkcell')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\LOKMAN\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "turkcell akıllı cihaz gayet iyi gorunuyo urun hizl..." with entities "[(0, 57, 'Turkcell')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\LOKMAN\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "turkcell akıllı cihaz olumsuz yönleri: tablet kula..." with entities "[(0, 69, 'Turkcell')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\LOKMAN\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "turkcell akıllı cihaz olumlu yönleri: kargoda bira..." with entities "[(0, 64, 'Turkcell')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\LOKMAN\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "turkcell akıllı cihaz olumsuz yönleri: müşteri kar..." with entities "[(0, 70, 'Turkcell')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\LOKMAN\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "turkcell akıllı cihaz 6 yaşındaki ikizlerim için a..." with entities "[(0, 62, 'Turkcell')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\LOKMAN\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "turkcell akıllı cihaz 1 yildir kullaniyorum. ag uz..." with entities "[(0, 59, 'Turkcell')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\LOKMAN\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "turkcell akıllı cihaz olumlu yönleri: biraz yavas ..." with entities "[(0, 71, 'Turkcell')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\LOKMAN\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "turkcell akıllı cihaz olumlu yönleri: fiatına göre..." with entities "[(0, 60, 'Turkcell')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\LOKMAN\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "turkcell akıllı cihaz açılışı bayağı bir uzun. biz..." with entities "[(0, 53, 'Turkcell')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\LOKMAN\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "turkcell akıllı cihaz olumlu yönleri: sadece kargo..." with entities "[(0, 62, 'Turkcell')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\LOKMAN\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "turkcell akıllı cihaz olumlu yönleri: jelatinli ga..." with entities "[(0, 71, 'Turkcell')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\LOKMAN\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "turkcell akıllı cihaz olumlu yönleri: fiyatına gör..." with entities "[(0, 62, 'Turkcell')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\LOKMAN\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "turkcell akıllı cihaz bu fiata alınacak en iyi tab..." with entities "[(0, 53, 'Turkcell')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\LOKMAN\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "turkcell akıllı cihaz olumlu yönleri: tabletin bat..." with entities "[(0, 66, 'Turkcell')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# ...
#   warnings.warn(
# c:\Users\LOKMAN\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "turkcell akıllı cihaz guzel is görür+" with entities "[(0, 9, 'Turkcell')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\LOKMAN\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "turkcell akıllı cihaz bazen çekmiyor. i̇dare eder+" with entities "[(0, 9, 'Turkcell')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\LOKMAN\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "turkcell akıllı cihaz ürün orijinal ve çok memnun ..." with entities "[(0, 56, 'Turkcell')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\LOKMAN\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "turkcell akıllı cihaz bir sıkıntı yok,anlatıldığı ..." with entities "[(0, 9, 'Turkcell')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\LOKMAN\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "turkcell akıllı cihaz gayet güzel sıkıntısız+" with entities "[(0, 9, 'Turkcell')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\LOKMAN\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "turkcell akıllı cihaz hızlı kargo. i̇çin teşekkür ..." with entities "[(0, 9, 'Turkcell')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\LOKMAN\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "turkcell akıllı cihaz çok iş görüyor,iyi bir tekno..." with entities "[(0, 24, 'Turkcell')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\LOKMAN\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "turkcell akıllı cihaz kullanımı ve çekim alanları ..." with entities "[(0, 61, 'Turkcell')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\LOKMAN\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "turkcell akıllı cihaz kargosu çok hızlı idi+" with entities "[(0, 9, 'Turkcell')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\LOKMAN\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "turkcell akıllı cihaz hızlı kargo, teşekkürler.+" with entities "[(0, 9, 'Turkcell')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\LOKMAN\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "turkcell akıllı cihaz i̇ş amaçlı kullanmak üzere a..." with entities "[(0, 61, 'Turkcell')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\LOKMAN\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "turkcell akıllı cihaz ürün hızlıca elime ulaştı. t..." with entities "[(0, 54, 'Turkcell')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\LOKMAN\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "turkcell akıllı cihaz ürünü 1 ay kullandım. imeisi..." with entities "[(0, 49, 'Turkcell')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\LOKMAN\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "turkcell akıllı cihaz performans mükemmel+" with entities "[(0, 9, 'Turkcell')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\LOKMAN\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "turkcell akıllı cihaz ürün çalışmıyor+" with entities "[(0, 9, 'Turkcell')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\LOKMAN\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "turkcell akıllı cihaz hayır, süresinde iade etmeme..." with entities "[(0, 62, 'Turkcell')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\LOKMAN\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "turkcell akıllı cihaz ürünün çekim hızı çok düşükt..." with entities "[(0, 60, 'Turkcell')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\LOKMAN\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "turkcell akıllı cihaz tam ıstediğim gibi orijinal+" with entities "[(0, 9, 'Turkcell')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\LOKMAN\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "turkcell akıllı cihaz garantili,sarj aleti icinde ..." with entities "[(0, 86, 'Turkcell')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\LOKMAN\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "turkcell akıllı cihaz gayet güzel kullanışlı+" with entities "[(0, 9, 'Turkcell')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\LOKMAN\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "turkcell akıllı cihaz cihazı beğenmedim+" with entities "[(0, 9, 'Turkcell')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\LOKMAN\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "turkcell akıllı cihaz verimli+" with entities "[(0, 9, 'Turkcell')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\LOKMAN\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "turkcell akıllı cihaz hızlı kargo, teşekkür ederim..." with entities "[(0, 9, 'Turkcell')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\LOKMAN\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "turkcell akıllı cihaz kapak çok zor açılıyor. kart..." with entities "[(0, 59, 'Turkcell')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\LOKMAN\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "turkcell akıllı cihaz ürünü 3 aydır kullanıyorum. ..." with entities "[(0, 57, 'Turkcell')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\LOKMAN\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "turkcell akıllı cihaz cok begendim iyi bir ürün+" with entities "[(0, 9, 'Turkcell')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\LOKMAN\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "turkcell akıllı cihaz evet......................+" with entities "[(0, 9, 'Turkcell')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\LOKMAN\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "turkcell akıllı cihaz verilen ücrete değiyor+" with entities "[(0, 9, 'Turkcell')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\LOKMAN\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "turkcell akıllı cihaz güzel ürün hızlı kargo+" with entities "[(0, 9, 'Turkcell')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\LOKMAN\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "turkcell akıllı cihaz sıfır ve kutusunda geldi, tu..." with entities "[(0, 58, 'Turkcell')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\LOKMAN\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "turkcell akıllı cihaz faturali kvk garanrti̇li̇ si..." with entities "[(0, 9, 'Turkcell')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\LOKMAN\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "turkcell akıllı cihaz ürün hari̇ka 3 tane aldik. k..." with entities "[(0, 62, 'Turkcell')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\LOKMAN\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "turkcell akıllı cihaz mukemmel hız ve müthiş özen...." with entities "[(0, 9, 'Turkcell')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\LOKMAN\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "turkcell akıllı cihaz bilmiyorum bu soruna yardım ..." with entities "[(0, 66, 'Turkcell')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\LOKMAN\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "turkcell akıllı cihaz ürün anlatıldığı gibi fatura..." with entities "[(0, 71, 'Turkcell')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\LOKMAN\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "turkcell akıllı cihaz çok hızlı gönderildi+" with entities "[(0, 9, 'Turkcell')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\LOKMAN\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "turkcell akıllı cihaz i̇yi fiyat zamanında teslima..." with entities "[(0, 66, 'Turkcell')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\LOKMAN\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "turkcell akıllı cihaz sipariş ettiğimde saat 13:30..." with entities "[(0, 59, 'Turkcell')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# {'ner': 469.71398532405635}
# {'ner': 82.05353517820689}
# {'ner': 72.85890368044286}
# {'ner': 76.08226929968654}
# {'ner': 75.654324968596}
# {'ner': 54.67932655330826}
# {'ner': 71.34317894768604}
# {'ner': 62.58624419669633}
# {'ner': 70.93654543873254}
# {'ner': 70.46991727399815}

# %%
nlp.to_disk("ner_model")

# %%
import spacy
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer

nlp = spacy.load("ner_model")
analyzer = SentimentIntensityAnalyzer()

text = "Turkcell akıllı cihaz eski tip olan t40 ve t50 yi kullandim ve t50 yi kullaniyorum hala gayet de iyi bi telefon t50 nin arka kapak yokdu sabit bir kasasi vardi ariza durumynda tlf cope gidiyordu tek sorun buydu yeni modellerde bunu ortadan kaldirmislar gordugum kadariyla seyyar kapak yok ise tavsiye etmiyorum geri kalan bu fiyatta normal ozellikler"
doc = nlp(text)

for ent in doc.ents:
    ent_text = ent.text
    ent_start = ent.start_char
    ent_end = ent.end_char
    ent_context = text[ent_start:ent_end]


    ent_sentiment = analyzer.polarity_scores(ent_context)
    sentiment_label = 'Neutral'
    if ent_sentiment['compound'] >= 0.05:
        sentiment_label = 'Positive'
    elif ent_sentiment['compound'] <= -0.05:
        sentiment_label = 'Negative'

    print(f"Entity: {ent.text}, Label: {ent.label_}, Sentiment: {sentiment_label}")
# Out:
# Entity: Turkcell akıllı cihaz eski tip olan t40 ve t50 yi kullandim ve t50 yi kullaniyorum hala gayet de iyi bi telefon t50 nin arka kapak yokdu sabit bir kasasi vardi ariza durumynda tlf cope gidiyordu tek sorun buydu yeni modellerde bunu ortadan kaldirmislar gordugum kadariyla seyyar kapak yok ise tavsiye etmiyorum geri kalan bu fiyatta normal ozellikler, Label: Turkcell, Sentiment: Neutral

# %%
nlp.to_disk('ner_model')

# %%
import spacy
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
import json

nlp = spacy.load("ner_model")
analyzer = SentimentIntensityAnalyzer()

text = "Turkcell akıllı cihaz eski tip olan t40 ve t50 yi kullandim ve t50 yi kullaniyorum hala gayet de iyi bi telefon t50 nin arka kapak yokdu sabit bir kasasi vardi ariza durumynda tlf cope gidiyordu tek sorun buydu yeni modellerde bunu ortadan kaldirmislar gordugum kadariyla seyyar kapak yok ise tavsiye etmiyorum geri kalan bu fiyatta normal ozellikler"
doc = nlp(text)

entity_list = []
results = []

for ent in doc.ents:
    ent_text = ent.text
    ent_start = ent.start_char
    ent_end = ent.end_char
    ent_context = text[ent_start:ent_end]
    ent_sentiment = analyzer.polarity_scores(ent_context)
    sentiment_label = 'nötr'
    if ent_sentiment['compound'] >= 0.05:
        sentiment_label = 'olumlu'
    elif ent_sentiment['compound'] <= -0.05:
        sentiment_label = 'olumsuz'
    entity_list.append(ent_text)
    results.append({
        "entity": ent_text,
        "sentiment": sentiment_label
    })
output = {
    "entity_list": entity_list,
    "results": results
}
print(json.dumps(output, ensure_ascii=False, indent=4))
# Out:
# {
#     "entity_list": [
#         "Turkcell akıllı cihaz eski tip olan t40 ve t50 yi kullandim ve t50 yi kullaniyorum hala gayet de iyi bi telefon t50 nin arka kapak yokdu sabit bir kasasi vardi ariza durumynda tlf cope gidiyordu tek sorun buydu yeni modellerde bunu ortadan kaldirmislar gordugum kadariyla seyyar kapak yok ise tavsiye etmiyorum geri kalan bu fiyatta normal ozellikler"
#     ],
#     "results": [
#         {
#             "entity": "Turkcell akıllı cihaz eski tip olan t40 ve t50 yi kullandim ve t50 yi kullaniyorum hala gayet de iyi bi telefon t50 nin arka kapak yokdu sabit bir kasasi vardi ariza durumynda tlf cope gidiyordu tek sorun buydu yeni modellerde bunu ortadan kaldirmislar gordugum kadariyla seyyar kapak yok ise tavsiye etmiyorum geri kalan bu fiyatta normal ozellikler",
#             "sentiment": "nötr"
#         }
#     ]
# }
